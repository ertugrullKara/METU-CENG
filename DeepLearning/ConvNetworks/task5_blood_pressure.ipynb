# %% [markdown]
# # Blood Pressure from PPG signal
#
# In this notebook, you should solve the problem in Task 4 (blood pressure estimation from PPG signal) in the first assignment (<a href="http://kovan.ceng.metu.edu.tr/~sinan/DL/HW1.html">HW1</a>) using a CNN architecture that you should construct using the layers and the network you developed in this HW.
#
# The notebook is intentionally composed of only this cell. You can copy-paste any text, data, cell, or code that you developed in this HW or HW1. You can add as many cells as you want. You can create files on the disk as freely as you like.

# %%
import random
import numpy as np
from metu.data_utils import load_dataset
from cs231n.regressor_trainer import RegressionTrainer
from cs231n.gradient_check import eval_numerical_gradient
from cs231n.classifiers.convnet import *
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Load the PPG dataset
# If your memory turns out to be sufficient, try loading a subset
def get_data(datafile, training_ratio=0.9, test_ratio=0.06, val_ratio=0.04):
  # Load the PPG training data 
  X, y = load_dataset(datafile, input_size)
  X.dump("X2.dat")
  y.dump("y2.dat")
#   X = np.load("X.dat")
#   y = np.load("y.dat")
  Xy = list(zip(X, y))
  np.random.shuffle(Xy)
  xx, yy = zip(*Xy)
  X = np.array(xx)
  y = np.array(yy)
  # TODO: Split the data into training, validation and test sets
  length=len(y)
  num_training=int(length*training_ratio)
  num_val = int(length*val_ratio)
  num_test = min((length-num_training-num_val), int(length*test_ratio))
  mask = range(num_training-1)
  X_train = X[mask]
  y_train = y[mask]
  mask = range(num_training, num_training+num_test)
  X_test = X[mask]
  y_test = y[mask]
  mask = range(num_training+num_test, num_training+num_test+num_val)
  X_val = X[mask]
  y_val = y[mask]
  
  return X_train, y_train, X_val, y_val, X_test, y_test

datafile = 'metu/dataset/part1.mat' #TODO: PATH to your data file
input_size = 900 # TODO: Size of the input of the network

X_train, y_train, X_val, y_val, X_test, y_test = get_data(datafile)
print "Number of instances in the training set: ", len(X_train)
print "Number of instances in the validation set: ", len(X_val)
print "Number of instances in the testing set: ", len(X_test)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# Number of instances in the training set:  26999
# Number of instances in the validation set:  1200
# Number of instances in the testing set:  1800

# %%
print X_train.shape, y_train.shape

X_train_r = X_train.reshape((X_train.shape[0], 1, 1, 900))
X_val_r = X_val.reshape((X_val.shape[0], 1, 1, 900))
X_test_r = X_test.reshape((X_test.shape[0], 1, 1, 900))

print X_train_r.shape, X_val_r.shape
# Out:
# (26999, 900) (26999, 2)
# (26999, 1, 1, 900) (1200, 1, 1, 900)

# %%
# X_train_r = np.tile(X_train_r, (3,1,1))
# X_val_r = np.tile(X_val_r, (3,1,1))

# %%
model = init_my_convnet(filter_size=5, num_filters=[32, 64], num_classes=2, num_crp=2, num_affine_layer=0, num_crcrp=0,
                       input_shape=X_train_r.shape[1:], loss="mse")
trainer = RegressionTrainer()
best_model, loss_history, train_acc_history, val_acc_history = trainer.train(
          X_train_r, y_train, X_val_r, y_val, model, my_convnet_imp,
          reg=0.001, momentum=0.9, learning_rate=0.0005, batch_size=50, num_epochs=2,
          acc_frequency=50, verbose=True)
# Out:
# starting iteration  0
# Finished epoch 0 / 2: cost 348867.508374, train: 6146181.827682, val 7482766.081055, lr 5.000000e-04
# starting iteration  10
# starting iteration  20
# starting iteration  30
# starting iteration  40
# starting iteration  50
# Finished epoch 0 / 2: cost 150156103015894496.000000, train: 316674025805.433777, val 380035747986.194641, lr 5.000000e-04
# starting iteration  60
# starting iteration  70
# starting iteration  80
# starting iteration  90
# starting iteration  100
# Finished epoch 0 / 2: cost 152722989094247168.000000, train: 2150512134.249236, val 2582188295.462914, lr 5.000000e-04
# starting iteration  110
# starting iteration  120
# starting iteration  130
# starting iteration  140
# starting iteration  150
# Finished epoch 0 / 2: cost 152660318698572384.000000, train: 3352156.339781, val 3958315.626402, lr 5.000000e-04
# starting iteration  160
# starting iteration  170
# starting iteration  180
# starting iteration  190
# starting iteration  200
# Finished epoch 0 / 2: cost 152584074477773920.000000, train: 246385.899811, val 290066.619820, lr 5.000000e-04
# starting iteration  210
# starting iteration  220
# starting iteration  230
# starting iteration  240
# starting iteration  250
# Finished epoch 0 / 2: cost 152507798251212832.000000, train: 150302.916725, val 186952.406087, lr 5.000000e-04
# starting iteration  260
# starting iteration  270
# starting iteration  280
# starting iteration  290
# starting iteration  300
# Finished epoch 0 / 2: cost 152431559793665024.000000, train: 150299.711265, val 186880.295014, lr 5.000000e-04
# starting iteration  310
# starting iteration  320
# starting iteration  330
# starting iteration  340
# starting iteration  350
# Finished epoch 0 / 2: cost 152355359445762272.000000, train: 153053.895270, val 188244.839742, lr 5.000000e-04
# starting iteration  360
# starting iteration  370
# starting iteration  380
# starting iteration  390
# starting iteration  400
# Finished epoch 0 / 2: cost 152279197190313472.000000, train: 150325.899621, val 186945.078051, lr 5.000000e-04
# starting iteration  410
# starting iteration  420
# starting iteration  430
# starting iteration  440
# starting iteration  450
# Finished epoch 0 / 2: cost 152203073008280128.000000, train: 155591.244512, val 186950.779117, lr 5.000000e-04
# starting iteration  460
# starting iteration  470
# starting iteration  480
# starting iteration  490
# starting iteration  500
# Finished epoch 0 / 2: cost 152126986880631168.000000, train: 148538.591026, val 187139.797756, lr 5.000000e-04
# starting iteration  510
# starting iteration  520
# starting iteration  530
# Finished epoch 1 / 2: cost 152069186862684640.000000, train: 150657.577377, val 187270.697558, lr 4.750000e-04
# starting iteration  540
# starting iteration  550
# Finished epoch 1 / 2: cost 152051305569491520.000000, train: 150506.274633, val 187062.787490, lr 4.750000e-04
# starting iteration  560
# starting iteration  570
# starting iteration  580
# starting iteration  590
# starting iteration  600
# Finished epoch 1 / 2: cost 151978881519064064.000000, train: 159067.762875, val 187209.639950, lr 4.750000e-04
# starting iteration  610
# starting iteration  620
# starting iteration  630
# starting iteration  640
# starting iteration  650
# Finished epoch 1 / 2: cost 151906704335721216.000000, train: 150888.548116, val 187042.426586, lr 4.750000e-04
# starting iteration  660
# starting iteration  670
# starting iteration  680
# starting iteration  690
# starting iteration  700
# Finished epoch 1 / 2: cost 151834562524979104.000000, train: 161550.510327, val 187243.731280, lr 4.750000e-04
# starting iteration  710
# starting iteration  720
# starting iteration  730
# starting iteration  740
# starting iteration  750
# Finished epoch 1 / 2: cost 151762454980648096.000000, train: 159185.587060, val 188865.209525, lr 4.750000e-04
# starting iteration  760
# starting iteration  770
# starting iteration  780
# starting iteration  790
# starting iteration  800
# Finished epoch 1 / 2: cost 151690381680842784.000000, train: 161869.929360, val 187397.296423, lr 4.750000e-04
# starting iteration  810
# starting iteration  820
# starting iteration  830
# starting iteration  840
# starting iteration  850
# Finished epoch 1 / 2: cost 151618342609266688.000000, train: 150023.733421, val 187270.866822, lr 4.750000e-04
# starting iteration  860
# starting iteration  870
# starting iteration  880
# starting iteration  890
# starting iteration  900
# Finished epoch 1 / 2: cost 151546337749668672.000000, train: 161689.024781, val 187212.871771, lr 4.750000e-04
# starting iteration  910
# starting iteration  920
# starting iteration  930
# starting iteration  940
# starting iteration  950
# Finished epoch 1 / 2: cost 151474367085803648.000000, train: 158016.155521, val 187042.699459, lr 4.750000e-04
# starting iteration  960
# starting iteration  970
# starting iteration  980
# starting iteration  990
# starting iteration  1000
# Finished epoch 1 / 2: cost 151402430601423904.000000, train: 155078.009617, val 188010.543942, lr 4.750000e-04
# starting iteration  1010
# starting iteration  1020
# starting iteration  1030
# starting iteration  1040
# starting iteration  1050
# Finished epoch 1 / 2: cost 151330528280304032.000000, train: 150311.831102, val 187342.244372, lr 4.750000e-04
# starting iteration  1060
# starting iteration  1070
# Finished epoch 2 / 2: cost 151291715226270688.000000, train: 156123.863228, val 187206.595065, lr 4.512500e-04
# finished optimization. best validation accuracy: 186880.295014

# %%
best_model_noaff = best_model

# %%
model = init_my_convnet(filter_size=5, num_filters=[32, 64], num_classes=2, num_crp=2, num_affine_layer=2, num_crcrp=0,
                       input_shape=X_train_r.shape[1:], loss="mse")
trainer = RegressionTrainer()
best_model, loss_history, train_acc_history, val_acc_history = trainer.train(
          X_train_r, y_train, X_val_r, y_val, model, my_convnet_imp,
          reg=0.001, momentum=0.9, learning_rate=5e-7, batch_size=50, num_epochs=2,
          acc_frequency=50, verbose=True)
# Out:
# starting iteration  0
# Finished epoch 0 / 2: cost 347866.515081, train: 6492646.889001, val 7906880.579876, lr 5.000000e-07
# starting iteration  10
# starting iteration  20
# starting iteration  30
# starting iteration  40
# starting iteration  50
# Finished epoch 0 / 2: cost 295953.445039, train: 6597561.882409, val 7746855.142208, lr 5.000000e-07
# starting iteration  60
# starting iteration  70
# starting iteration  80
# starting iteration  90
# starting iteration  100
# Finished epoch 0 / 2: cost 291126.753877, train: 6393147.634619, val 7559643.681655, lr 5.000000e-07
# starting iteration  110
# starting iteration  120
# starting iteration  130
# starting iteration  140
# starting iteration  150
# Finished epoch 0 / 2: cost 288829.707408, train: 5998289.484902, val 7363322.143822, lr 5.000000e-07
# starting iteration  160
# starting iteration  170
# starting iteration  180
# starting iteration  190
# starting iteration  200
# Finished epoch 0 / 2: cost 297423.337838, train: 5702201.298564, val 6905004.276089, lr 5.000000e-07
# starting iteration  210
# starting iteration  220
# starting iteration  230
# starting iteration  240
# starting iteration  250
# Finished epoch 0 / 2: cost 149721.220042, train: 2977813.658950, val 3562808.857462, lr 5.000000e-07
# starting iteration  260
# starting iteration  270
# starting iteration  280
# starting iteration  290
# starting iteration  300
# Finished epoch 0 / 2: cost 8516.427196, train: 154431.320080, val 187458.601656, lr 5.000000e-07
# starting iteration  310
# starting iteration  320
# starting iteration  330
# starting iteration  340
# starting iteration  350
# Finished epoch 0 / 2: cost 7225.156740, train: 151542.073347, val 187286.353651, lr 5.000000e-07
# starting iteration  360
# starting iteration  370
# starting iteration  380
# starting iteration  390
# starting iteration  400
# Finished epoch 0 / 2: cost 8331.025760, train: 162562.088626, val 187132.514725, lr 5.000000e-07
# starting iteration  410
# starting iteration  420
# starting iteration  430
# starting iteration  440
# starting iteration  450
# Finished epoch 0 / 2: cost 8540.134724, train: 154218.358809, val 187039.124570, lr 5.000000e-07
# starting iteration  460
# starting iteration  470
# starting iteration  480
# starting iteration  490
# starting iteration  500
# Finished epoch 0 / 2: cost 6158.280759, train: 161360.992755, val 186950.488824, lr 5.000000e-07
# starting iteration  510
# starting iteration  520
# starting iteration  530
# Finished epoch 1 / 2: cost 7973.141157, train: 153935.662010, val 187082.152182, lr 4.750000e-07
# starting iteration  540
# starting iteration  550
# Finished epoch 1 / 2: cost 8411.705685, train: 162293.205602, val 187561.620303, lr 4.750000e-07
# starting iteration  560
# starting iteration  570
# starting iteration  580
# starting iteration  590
# starting iteration  600
# Finished epoch 1 / 2: cost 7804.488552, train: 157085.977758, val 186878.103365, lr 4.750000e-07
# starting iteration  610
# starting iteration  620
# starting iteration  630
# starting iteration  640
# starting iteration  650
# Finished epoch 1 / 2: cost 9040.049747, train: 151413.345203, val 187475.041860, lr 4.750000e-07
# starting iteration  660
# starting iteration  670
# starting iteration  680
# starting iteration  690
# starting iteration  700
# Finished epoch 1 / 2: cost 6267.674941, train: 156763.126687, val 187130.535388, lr 4.750000e-07
# starting iteration  710
# starting iteration  720
# starting iteration  730
# starting iteration  740
# starting iteration  750
# Finished epoch 1 / 2: cost 8819.351209, train: 157974.529476, val 186901.557831, lr 4.750000e-07
# starting iteration  760
# starting iteration  770
# starting iteration  780
# starting iteration  790
# starting iteration  800
# Finished epoch 1 / 2: cost 8378.467649, train: 150884.159601, val 187018.700854, lr 4.750000e-07
# starting iteration  810
# starting iteration  820
# starting iteration  830
# starting iteration  840
# starting iteration  850
# Finished epoch 1 / 2: cost 7857.544065, train: 155600.896177, val 186938.960106, lr 4.750000e-07
# starting iteration  860
# starting iteration  870
# starting iteration  880
# starting iteration  890
# starting iteration  900
# Finished epoch 1 / 2: cost 7740.551882, train: 163440.868031, val 186989.945598, lr 4.750000e-07
# starting iteration  910
# starting iteration  920
# starting iteration  930
# starting iteration  940
# starting iteration  950
# Finished epoch 1 / 2: cost 9129.718960, train: 155233.874890, val 190540.839019, lr 4.750000e-07
# starting iteration  960
# starting iteration  970
# starting iteration  980
# starting iteration  990
# starting iteration  1000
# Finished epoch 1 / 2: cost 8637.740861, train: 160449.053410, val 188309.554062, lr 4.750000e-07
# starting iteration  1010
# starting iteration  1020
# starting iteration  1030
# starting iteration  1040
# starting iteration  1050
# Finished epoch 1 / 2: cost 10006.851117, train: 155336.496422, val 186890.392061, lr 4.750000e-07
# starting iteration  1060
# starting iteration  1070
# Finished epoch 2 / 2: cost 8736.175010, train: 163122.251446, val 187432.969301, lr 4.512500e-07
# finished optimization. best validation accuracy: 186878.103365

# %%
best_model_2aff = best_model

# %%
model = init_my_convnet(filter_size=5, num_filters=[32, 64], num_classes=2, num_crp=2, num_affine_layer=1, num_crcrp=0,
                       input_shape=X_train_r.shape[1:], loss="mse")
trainer = RegressionTrainer()
best_model, loss_history, train_acc_history, val_acc_history = trainer.train(
          X_train_r, y_train, X_val_r, y_val, model, my_convnet_imp,
          reg=0.001, momentum=0.9, learning_rate=5e-7, batch_size=50, num_epochs=2,
          acc_frequency=50, verbose=True)
# Out:
# starting iteration  0
# Finished epoch 0 / 2: cost 337760.438702, train: 6451228.764085, val 7906885.881865, lr 5.000000e-07
# starting iteration  10
# starting iteration  20
# starting iteration  30
# starting iteration  40
# starting iteration  50
# Finished epoch 0 / 2: cost 303648.210059, train: 6440251.771727, val 7746892.929233, lr 5.000000e-07
# starting iteration  60
# starting iteration  70
# starting iteration  80
# starting iteration  90
# starting iteration  100
# Finished epoch 0 / 2: cost 318687.653401, train: 6258306.559690, val 7559090.871935, lr 5.000000e-07
# starting iteration  110
# starting iteration  120
# starting iteration  130
# starting iteration  140
# starting iteration  150
# Finished epoch 0 / 2: cost 22091.556653, train: 542530.897793, val 682947.032484, lr 5.000000e-07
# starting iteration  160
# starting iteration  170
# starting iteration  180
# starting iteration  190
# starting iteration  200
# Finished epoch 0 / 2: cost 9948.622473, train: 171452.292061, val 211047.131785, lr 5.000000e-07
# starting iteration  210
# starting iteration  220
# starting iteration  230
# starting iteration  240
# starting iteration  250
# Finished epoch 0 / 2: cost 8786.386368, train: 184199.162250, val 224710.633093, lr 5.000000e-07
# starting iteration  260
# starting iteration  270
# starting iteration  280
# starting iteration  290
# starting iteration  300
# Finished epoch 0 / 2: cost 10388.358270, train: 193504.935732, val 220006.066546, lr 5.000000e-07
# starting iteration  310
# starting iteration  320
# starting iteration  330
# starting iteration  340
# starting iteration  350
# Finished epoch 0 / 2: cost 7227.287487, train: 158161.435532, val 188699.051595, lr 5.000000e-07
# starting iteration  360
# starting iteration  370
# starting iteration  380
# starting iteration  390
# starting iteration  400
# Finished epoch 0 / 2: cost 8086.715531, train: 164700.221737, val 192921.069223, lr 5.000000e-07
# starting iteration  410
# starting iteration  420
# starting iteration  430
# starting iteration  440
# starting iteration  450
# Finished epoch 0 / 2: cost 7427.914043, train: 167062.035140, val 197003.499552, lr 5.000000e-07
# starting iteration  460
# starting iteration  470
# starting iteration  480
# starting iteration  490
# starting iteration  500
# Finished epoch 0 / 2: cost 9542.614010, train: 160454.638433, val 202575.062060, lr 5.000000e-07
# starting iteration  510
# starting iteration  520
# starting iteration  530
# Finished epoch 1 / 2: cost 8402.869419, train: 164381.012671, val 188737.000022, lr 4.750000e-07
# starting iteration  540
# starting iteration  550
# Finished epoch 1 / 2: cost 8874.374714, train: 162538.663005, val 197517.200763, lr 4.750000e-07
# starting iteration  560
# starting iteration  570
# starting iteration  580
# starting iteration  590
# starting iteration  600
# Finished epoch 1 / 2: cost 8537.246620, train: 155714.595700, val 190765.856811, lr 4.750000e-07
# starting iteration  610
# starting iteration  620
# starting iteration  630
# starting iteration  640
# starting iteration  650
# Finished epoch 1 / 2: cost 6722.900788, train: 153149.439683, val 188808.198610, lr 4.750000e-07
# starting iteration  660
# starting iteration  670
# starting iteration  680
# starting iteration  690
# starting iteration  700
# Finished epoch 1 / 2: cost 7439.340926, train: 162661.917221, val 187468.100439, lr 4.750000e-07
# starting iteration  710
# starting iteration  720
# starting iteration  730
# starting iteration  740
# starting iteration  750
# Finished epoch 1 / 2: cost 6763.471992, train: 178978.580632, val 220702.955568, lr 4.750000e-07
# starting iteration  760
# starting iteration  770
# starting iteration  780
# starting iteration  790
# starting iteration  800
# Finished epoch 1 / 2: cost 8939.025927, train: 153262.192337, val 189745.345600, lr 4.750000e-07
# starting iteration  810
# starting iteration  820
# starting iteration  830
# starting iteration  840
# starting iteration  850
# Finished epoch 1 / 2: cost 7996.783569, train: 156501.434303, val 190687.048960, lr 4.750000e-07
# starting iteration  860
# starting iteration  870
# starting iteration  880
# starting iteration  890
# starting iteration  900
# Finished epoch 1 / 2: cost 7035.415094, train: 169482.846782, val 196343.612163, lr 4.750000e-07
# starting iteration  910
# starting iteration  920
# starting iteration  930
# starting iteration  940
# starting iteration  950
# Finished epoch 1 / 2: cost 7820.123745, train: 167824.827185, val 210780.839832, lr 4.750000e-07
# starting iteration  960
# starting iteration  970
# starting iteration  980
# starting iteration  990
# starting iteration  1000
# Finished epoch 1 / 2: cost 7710.637770, train: 154483.137153, val 187429.434319, lr 4.750000e-07
# starting iteration  1010
# starting iteration  1020
# starting iteration  1030
# starting iteration  1040
# starting iteration  1050
# Finished epoch 1 / 2: cost 8441.341437, train: 216501.446084, val 263327.154663, lr 4.750000e-07
# starting iteration  1060
# starting iteration  1070
# Finished epoch 2 / 2: cost 11125.196740, train: 200601.551272, val 251246.350703, lr 4.512500e-07
# finished optimization. best validation accuracy: 187429.434319

# %%
best_model_1aff = best_model

# %%
init_my_convnet(filter_size=5, num_filters=[32, 64], num_classes=2, num_crp=2, num_affine_layer=1, num_crcrp=0,
                       input_shape=X_train_r.shape[1:], loss="mse")
model = best_model_1aff
trainer = RegressionTrainer()
best_model, loss_history, train_acc_history, val_acc_history = trainer.train(
          X_train_r, y_train, X_val_r, y_val, model, my_convnet_imp,
          reg=0.001, momentum=0.9, learning_rate=1e-7, batch_size=50, num_epochs=5,
          acc_frequency=50, verbose=True)
# Out:
# starting iteration  0
# Finished epoch 0 / 5: cost 6755.513847, train: 166978.844367, val 187364.554717, lr 1.000000e-07
# starting iteration  10
# starting iteration  20
# starting iteration  30
# starting iteration  40
# starting iteration  50
# Finished epoch 0 / 5: cost 7138.282666, train: 147113.317522, val 187018.700665, lr 1.000000e-07
# starting iteration  60
# starting iteration  70
# starting iteration  80
# starting iteration  90
# starting iteration  100
# Finished epoch 0 / 5: cost 8173.770006, train: 155950.697468, val 187465.128517, lr 1.000000e-07
# starting iteration  110
# starting iteration  120
# starting iteration  130
# starting iteration  140
# starting iteration  150
# Finished epoch 0 / 5: cost 7520.090207, train: 154107.219205, val 188617.645439, lr 1.000000e-07
# starting iteration  160
# starting iteration  170
# starting iteration  180
# starting iteration  190
# starting iteration  200
# Finished epoch 0 / 5: cost 9859.643529, train: 156733.244346, val 187266.426053, lr 1.000000e-07
# starting iteration  210
# starting iteration  220
# starting iteration  230
# starting iteration  240
# starting iteration  250
# Finished epoch 0 / 5: cost 9163.606347, train: 156478.994693, val 187354.972140, lr 1.000000e-07
# starting iteration  260
# starting iteration  270
# starting iteration  280
# starting iteration  290
# starting iteration  300
# Finished epoch 0 / 5: cost 9761.255477, train: 152406.765755, val 187167.952972, lr 1.000000e-07
# starting iteration  310
# starting iteration  320
# starting iteration  330
# starting iteration  340
# starting iteration  350
# Finished epoch 0 / 5: cost 9625.752307, train: 150836.689947, val 188569.504312, lr 1.000000e-07
# starting iteration  360
# starting iteration  370
# starting iteration  380
# starting iteration  390
# starting iteration  400
# Finished epoch 0 / 5: cost 6567.479987, train: 158646.719551, val 187518.226299, lr 1.000000e-07
# starting iteration  410
# starting iteration  420
# starting iteration  430
# starting iteration  440
# starting iteration  450
# Finished epoch 0 / 5: cost 8056.259968, train: 163171.109983, val 187167.407219, lr 1.000000e-07
# starting iteration  460
# starting iteration  470
# starting iteration  480
# starting iteration  490
# starting iteration  500
# Finished epoch 0 / 5: cost 9066.129067, train: 154887.606534, val 191969.320211, lr 1.000000e-07
# starting iteration  510
# starting iteration  520
# starting iteration  530
# Finished epoch 1 / 5: cost 8984.391147, train: 167961.010837, val 188493.329704, lr 9.500000e-08
# starting iteration  540
# starting iteration  550
# Finished epoch 1 / 5: cost 11682.389735, train: 155388.573261, val 188375.988911, lr 9.500000e-08
# starting iteration  560
# starting iteration  570
# starting iteration  580
# starting iteration  590
# starting iteration  600
# Finished epoch 1 / 5: cost 8047.996838, train: 155253.794812, val 187151.009745, lr 9.500000e-08
# starting iteration  610
# starting iteration  620
# starting iteration  630
# starting iteration  640
# starting iteration  650
# Finished epoch 1 / 5: cost 6989.363936, train: 147451.175535, val 187786.493748, lr 9.500000e-08
# starting iteration  660
# starting iteration  670
# starting iteration  680
# starting iteration  690
# starting iteration  700
# Finished epoch 1 / 5: cost 8165.736380, train: 160284.899271, val 189681.294943, lr 9.500000e-08
# starting iteration  710
# starting iteration  720
# starting iteration  730
# starting iteration  740
# starting iteration  750
# Finished epoch 1 / 5: cost 6413.507268, train: 159104.811734, val 186877.958590, lr 9.500000e-08
# starting iteration  760
# starting iteration  770
# starting iteration  780
# starting iteration  790
# starting iteration  800
# Finished epoch 1 / 5: cost 8236.507407, train: 149187.234769, val 187954.110270, lr 9.500000e-08
# starting iteration  810
# starting iteration  820
# starting iteration  830
# starting iteration  840
# starting iteration  850
# Finished epoch 1 / 5: cost 8733.802228, train: 158581.314503, val 190259.652132, lr 9.500000e-08
# starting iteration  860
# starting iteration  870
# starting iteration  880
# starting iteration  890
# starting iteration  900
# Finished epoch 1 / 5: cost 9388.355830, train: 161444.207791, val 188552.777555, lr 9.500000e-08
# starting iteration  910
# starting iteration  920
# starting iteration  930
# starting iteration  940
# starting iteration  950
# Finished epoch 1 / 5: cost 8198.057815, train: 159384.114787, val 187012.648770, lr 9.500000e-08
# starting iteration  960
# starting iteration  970
# starting iteration  980
# starting iteration  990
# starting iteration  1000
# Finished epoch 1 / 5: cost 8363.718003, train: 165766.744689, val 192139.884739, lr 9.500000e-08
# starting iteration  1010
# starting iteration  1020
# starting iteration  1030
# starting iteration  1040
# starting iteration  1050
# Finished epoch 1 / 5: cost 8046.098284, train: 175626.019277, val 197673.605741, lr 9.500000e-08
# starting iteration  1060
# starting iteration  1070
# Finished epoch 2 / 5: cost 8344.889176, train: 172169.821382, val 187028.217624, lr 9.025000e-08
# starting iteration  1080
# starting iteration  1090
# starting iteration  1100
# Finished epoch 2 / 5: cost 6861.631304, train: 146262.964630, val 186946.313555, lr 9.025000e-08
# starting iteration  1110
# starting iteration  1120
# starting iteration  1130
# starting iteration  1140
# starting iteration  1150
# Finished epoch 2 / 5: cost 6659.830576, train: 147337.073912, val 189177.352178, lr 9.025000e-08
# starting iteration  1160
# starting iteration  1170
# starting iteration  1180
# starting iteration  1190
# starting iteration  1200
# Finished epoch 2 / 5: cost 6941.485505, train: 162941.565740, val 187333.787672, lr 9.025000e-08
# starting iteration  1210
# starting iteration  1220
# starting iteration  1230
# starting iteration  1240
# starting iteration  1250
# Finished epoch 2 / 5: cost 8902.442770, train: 156099.575380, val 188285.740192, lr 9.025000e-08
# starting iteration  1260
# starting iteration  1270
# starting iteration  1280
# starting iteration  1290
# starting iteration  1300
# Finished epoch 2 / 5: cost 9718.072642, train: 165397.260762, val 188301.503582, lr 9.025000e-08
# starting iteration  1310
# starting iteration  1320
# starting iteration  1330
# starting iteration  1340
# starting iteration  1350
# Finished epoch 2 / 5: cost 7470.266081, train: 167262.500005, val 189637.998139, lr 9.025000e-08
# starting iteration  1360
# starting iteration  1370
# starting iteration  1380
# starting iteration  1390
# starting iteration  1400
# Finished epoch 2 / 5: cost 5333.450000, train: 160617.670863, val 190093.515031, lr 9.025000e-08
# starting iteration  1410
# starting iteration  1420
# starting iteration  1430
# starting iteration  1440
# starting iteration  1450
# Finished epoch 2 / 5: cost 7162.369562, train: 157943.082238, val 188129.368655, lr 9.025000e-08
# starting iteration  1460
# starting iteration  1470
# starting iteration  1480
# starting iteration  1490
# starting iteration  1500
# Finished epoch 2 / 5: cost 8532.132001, train: 155635.270174, val 187181.256081, lr 9.025000e-08
# starting iteration  1510
# starting iteration  1520
# starting iteration  1530
# starting iteration  1540
# starting iteration  1550
# Finished epoch 2 / 5: cost 7746.348565, train: 166149.883700, val 187114.655442, lr 9.025000e-08
# starting iteration  1560
# starting iteration  1570
# starting iteration  1580
# starting iteration  1590
# starting iteration  1600
# Finished epoch 2 / 5: cost 8499.397853, train: 149563.777693, val 187995.401330, lr 9.025000e-08
# starting iteration  1610
# Finished epoch 3 / 5: cost 5640.744737, train: 153493.619107, val 186955.119940, lr 8.573750e-08
# starting iteration  1620
# starting iteration  1630
# starting iteration  1640
# starting iteration  1650
# Finished epoch 3 / 5: cost 8390.309091, train: 157489.507767, val 187037.195303, lr 8.573750e-08
# starting iteration  1660
# starting iteration  1670
# starting iteration  1680
# starting iteration  1690
# starting iteration  1700
# Finished epoch 3 / 5: cost 7613.085415, train: 157235.102484, val 196075.672628, lr 8.573750e-08
# starting iteration  1710
# starting iteration  1720
# starting iteration  1730
# starting iteration  1740
# starting iteration  1750
# Finished epoch 3 / 5: cost 7755.828288, train: 152759.183002, val 187697.376431, lr 8.573750e-08
# starting iteration  1760
# starting iteration  1770
# starting iteration  1780
# starting iteration  1790
# starting iteration  1800
# Finished epoch 3 / 5: cost 6588.023079, train: 153792.818017, val 188174.337239, lr 8.573750e-08
# starting iteration  1810
# starting iteration  1820
# starting iteration  1830
# starting iteration  1840
# starting iteration  1850
# Finished epoch 3 / 5: cost 8712.651680, train: 157353.907827, val 191381.556036, lr 8.573750e-08
# starting iteration  1860
# starting iteration  1870
# starting iteration  1880
# starting iteration  1890
# starting iteration  1900
# Finished epoch 3 / 5: cost 7478.049787, train: 160277.868541, val 188464.172738, lr 8.573750e-08
# starting iteration  1910
# starting iteration  1920
# starting iteration  1930
# starting iteration  1940
# starting iteration  1950
# Finished epoch 3 / 5: cost 7997.291300, train: 174076.707666, val 188729.931754, lr 8.573750e-08
# starting iteration  1960
# starting iteration  1970
# starting iteration  1980
# starting iteration  1990
# starting iteration  2000
# Finished epoch 3 / 5: cost 7565.516710, train: 162320.925260, val 192227.531701, lr 8.573750e-08
# starting iteration  2010
# starting iteration  2020
# starting iteration  2030
# starting iteration  2040
# starting iteration  2050
# Finished epoch 3 / 5: cost 7500.574364, train: 152100.570712, val 187387.462992, lr 8.573750e-08
# starting iteration  2060
# starting iteration  2070
# starting iteration  2080
# starting iteration  2090
# starting iteration  2100
# Finished epoch 3 / 5: cost 6603.666749, train: 156199.058335, val 188199.929668, lr 8.573750e-08
# starting iteration  2110
# starting iteration  2120
# starting iteration  2130
# starting iteration  2140
# starting iteration  2150
# Finished epoch 3 / 5: cost 7307.286623, train: 144103.057969, val 188432.778653, lr 8.573750e-08
# Finished epoch 4 / 5: cost 7641.652792, train: 150667.997264, val 189224.687738, lr 8.145062e-08
# starting iteration  2160
# starting iteration  2170
# starting iteration  2180
# starting iteration  2190
# starting iteration  2200
# Finished epoch 4 / 5: cost 6386.206523, train: 150823.801597, val 186874.959306, lr 8.145062e-08
# starting iteration  2210
# starting iteration  2220
# starting iteration  2230
# starting iteration  2240
# starting iteration  2250
# Finished epoch 4 / 5: cost 6462.701065, train: 158017.480973, val 187040.461906, lr 8.145062e-08
# starting iteration  2260
# starting iteration  2270
# starting iteration  2280
# starting iteration  2290
# starting iteration  2300
# Finished epoch 4 / 5: cost 8331.875753, train: 156424.351738, val 186947.344530, lr 8.145062e-08
# starting iteration  2310
# starting iteration  2320
# starting iteration  2330
# starting iteration  2340
# starting iteration  2350
# Finished epoch 4 / 5: cost 8879.448506, train: 159750.949122, val 190828.404972, lr 8.145062e-08
# starting iteration  2360
# starting iteration  2370
# starting iteration  2380
# starting iteration  2390
# starting iteration  2400
# Finished epoch 4 / 5: cost 10535.087377, train: 162999.359526, val 190526.586999, lr 8.145062e-08
# starting iteration  2410
# starting iteration  2420
# starting iteration  2430
# starting iteration  2440
# starting iteration  2450
# Finished epoch 4 / 5: cost 10224.464935, train: 154953.655632, val 189291.583528, lr 8.145062e-08
# starting iteration  2460
# starting iteration  2470
# starting iteration  2480
# starting iteration  2490
# starting iteration  2500
# Finished epoch 4 / 5: cost 7185.982196, train: 170887.510465, val 195061.253598, lr 8.145062e-08
# starting iteration  2510
# starting iteration  2520
# starting iteration  2530
# starting iteration  2540
# starting iteration  2550
# Finished epoch 4 / 5: cost 8871.515079, train: 166660.096646, val 187735.370898, lr 8.145062e-08
# starting iteration  2560
# starting iteration  2570
# starting iteration  2580
# starting iteration  2590
# starting iteration  2600
# Finished epoch 4 / 5: cost 7410.100412, train: 148262.442140, val 187832.175027, lr 8.145062e-08
# starting iteration  2610
# starting iteration  2620
# starting iteration  2630
# starting iteration  2640
# starting iteration  2650
# Finished epoch 4 / 5: cost 7247.480489, train: 158105.690707, val 191183.179358, lr 8.145062e-08
# starting iteration  2660
# starting iteration  2670
# starting iteration  2680
# starting iteration  2690
# Finished epoch 5 / 5: cost 9392.216308, train: 169052.278700, val 195429.480681, lr 7.737809e-08
# finished optimization. best validation accuracy: 186874.959306

# %%
best_model_1aff = best_model

# %%
np.save("noaff.npy", best_model_noaff)
np.save("1aff.npy", best_model_1aff)
np.save("2aff.npy", best_model_2aff)

# %%
test = np.load("noaff.npy")
# print test.item()

# %%
model = init_my_convnet(filter_size=5, num_filters=[32, 64, 128], num_classes=2, num_crp=3, num_affine_layer=1, num_crcrp=0,
                       input_shape=X_train_r.shape[1:], loss="mse")
trainer = RegressionTrainer()
best_model, loss_history, train_acc_history, val_acc_history = trainer.train(
          X_train_r, y_train, X_val_r, y_val, model, my_convnet_imp,
          reg=0.001, momentum=0.9, learning_rate=5e-7, batch_size=50, num_epochs=2,
          acc_frequency=50, verbose=True)
# Out:
# starting iteration  0
# Finished epoch 0 / 2: cost 333628.410090, train: 6483035.335136, val 7874264.058415, lr 5.000000e-07
# starting iteration  10
# starting iteration  20
# starting iteration  30
# starting iteration  40
# starting iteration  50
# Finished epoch 0 / 2: cost 338326.899467, train: 6535712.050775, val 7715172.624148, lr 5.000000e-07
# starting iteration  60
# starting iteration  70
# starting iteration  80
# starting iteration  90
# starting iteration  100
# Finished epoch 0 / 2: cost 312457.176230, train: 6297834.319674, val 7527581.372066, lr 5.000000e-07
# starting iteration  110
# starting iteration  120
# starting iteration  130
# starting iteration  140
# starting iteration  150
# Finished epoch 0 / 2: cost 8795.765592, train: 711662.276686, val 855989.036904, lr 5.000000e-07
# starting iteration  160
# starting iteration  170
# starting iteration  180
# starting iteration  190
# starting iteration  200
# Finished epoch 0 / 2: cost 7089.235861, train: 153329.554815, val 188876.464680, lr 5.000000e-07
# starting iteration  210
# starting iteration  220
# starting iteration  230
# starting iteration  240
# starting iteration  250
# Finished epoch 0 / 2: cost 7708.430978, train: 159712.387492, val 189531.935223, lr 5.000000e-07
# starting iteration  260
# starting iteration  270
# starting iteration  280
# starting iteration  290
# starting iteration  300
# Finished epoch 0 / 2: cost 7919.155203, train: 161327.698976, val 191822.111279, lr 5.000000e-07
# starting iteration  310
# starting iteration  320
# starting iteration  330
# starting iteration  340
# starting iteration  350
# Finished epoch 0 / 2: cost 7976.263081, train: 162270.451129, val 188347.641984, lr 5.000000e-07
# starting iteration  360
# starting iteration  370
# starting iteration  380
# starting iteration  390
# starting iteration  400
# Finished epoch 0 / 2: cost 8881.320990, train: 166605.830567, val 188707.720835, lr 5.000000e-07
# starting iteration  410
# starting iteration  420
# starting iteration  430
# starting iteration  440
# starting iteration  450
# Finished epoch 0 / 2: cost 8729.464123, train: 176144.528051, val 194539.303079, lr 5.000000e-07
# starting iteration  460
# starting iteration  470
# starting iteration  480
# starting iteration  490
# starting iteration  500
# Finished epoch 0 / 2: cost 5174.623759, train: 162834.226074, val 192017.621360, lr 5.000000e-07
# starting iteration  510
# starting iteration  520
# starting iteration  530
# Finished epoch 1 / 2: cost 6762.075165, train: 152334.461853, val 188701.257306, lr 4.750000e-07
# starting iteration  540
# starting iteration  550
# Finished epoch 1 / 2: cost 7458.089155, train: 150714.751809, val 189631.147283, lr 4.750000e-07
# starting iteration  560
# starting iteration  570
# starting iteration  580
# starting iteration  590
# starting iteration  600
# Finished epoch 1 / 2: cost 6342.403752, train: 161757.575036, val 194077.277470, lr 4.750000e-07
# starting iteration  610
# starting iteration  620
# starting iteration  630
# starting iteration  640
# starting iteration  650
# Finished epoch 1 / 2: cost 8785.344610, train: 164812.268139, val 190598.878056, lr 4.750000e-07
# starting iteration  660
# starting iteration  670
# starting iteration  680
# starting iteration  690
# starting iteration  700
# Finished epoch 1 / 2: cost 9327.712567, train: 159990.683427, val 193281.832541, lr 4.750000e-07
# starting iteration  710
# starting iteration  720
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-6-edde5750a61b> in <module>()
#       5           X_train_r, y_train, X_val_r, y_val, model, my_convnet_imp,
#       6           reg=0.001, momentum=0.9, learning_rate=5e-7, batch_size=50, num_epochs=2,
# ----> 7           acc_frequency=50, verbose=True)
#
# /home/ertugrulcan46/env/HW2/cs231n/regressor_trainer.pyc in train(self, X, y, X_val, y_val, model, loss_function, reg, learning_rate, momentum, learning_rate_decay, update, sample_batches, num_epochs, batch_size, acc_frequency, verbose)
#      80
#      81       # evaluate cost and gradient
# ---> 82       cost, grads = loss_function(X_batch, model, y_batch, reg)
#      83       loss_history.append(cost)
#      84
#
# /home/ertugrulcan46/env/HW2/cs231n/classifiers/convnet.py in my_convnet_imp(X, model, y, reg)
#     185   tmp=-1
#     186   for i in range(num_affine_layer):
# --> 187     da_tmp, dW_tmp, db_tmp = affine_backward(dscores, cache[tmp])
#     188     dscores = da_tmp
#     189     dW[i]=dW_tmp
#
# /home/ertugrulcan46/env/HW2/cs231n/layers.pyc in affine_backward(dout, cache)
#      53   dx = np.dot(dout, w.T).reshape(x.shape)
#      54   x = x.reshape(x.shape[0], w.shape[0])
# ---> 55   dw = np.dot(x.T, dout)
#      56   db = np.sum(dout, axis=0)
#      57   return dx, dw, db
#
# KeyboardInterrupt:

# %%
model = init_my_convnet(filter_size=5, num_filters=[32, 64, 128], num_classes=2, num_crp=2, num_affine_layer=2, num_crcrp=0,
                       input_shape=X_train_r.shape[1:], loss="mse")
trainer = RegressionTrainer()
best_model, loss_history, train_acc_history, val_acc_history = trainer.train(
          X_train_r, y_train, X_val_r, y_val, model, my_convnet_imp,
          reg=0.001, momentum=0.9, learning_rate=1e-7, batch_size=50, num_epochs=2,
          acc_frequency=50, verbose=True)
# Out:
# starting iteration  0
# Finished epoch 0 / 2: cost 348920.344617, train: 6574767.135864, val 7874572.668643, lr 1.000000e-07
# starting iteration  10
# starting iteration  20
# starting iteration  30
# starting iteration  40
# starting iteration  50
# Finished epoch 0 / 2: cost 340695.294096, train: 6543988.568163, val 7842261.811464, lr 1.000000e-07
# starting iteration  60
# starting iteration  70
# starting iteration  80
# starting iteration  90
# starting iteration  100
# Finished epoch 0 / 2: cost 340790.913687, train: 6440832.935990, val 7804021.804057, lr 1.000000e-07
# starting iteration  110
# starting iteration  120
# starting iteration  130
# starting iteration  140
# starting iteration  150
# Finished epoch 0 / 2: cost 323066.890675, train: 6657876.425066, val 7766031.867662, lr 1.000000e-07
# starting iteration  160
# starting iteration  170
# starting iteration  180
# starting iteration  190
# starting iteration  200
# Finished epoch 0 / 2: cost 342104.639209, train: 6521025.748586, val 7728241.467558, lr 1.000000e-07
# starting iteration  210
# starting iteration  220
# starting iteration  230
# starting iteration  240
# starting iteration  250
# Finished epoch 0 / 2: cost 323132.919312, train: 6381398.828882, val 7690500.044905, lr 1.000000e-07
# starting iteration  260
# starting iteration  270
# starting iteration  280
# starting iteration  290
# starting iteration  300
# Finished epoch 0 / 2: cost 307643.081888, train: 6294031.929851, val 7653025.966204, lr 1.000000e-07
# starting iteration  310
# starting iteration  320
# starting iteration  330
# starting iteration  340
# starting iteration  350
# Finished epoch 0 / 2: cost 321761.210453, train: 6341867.634314, val 7615670.664053, lr 1.000000e-07
# starting iteration  360
# starting iteration  370
# starting iteration  380
# starting iteration  390
# starting iteration  400
# Finished epoch 0 / 2: cost 309066.980589, train: 6322649.764979, val 7578223.007096, lr 1.000000e-07
# starting iteration  410
# starting iteration  420
# starting iteration  430
# starting iteration  440
# starting iteration  450
# Finished epoch 0 / 2: cost 309731.857427, train: 6315551.388070, val 7540542.303271, lr 1.000000e-07
# starting iteration  460
# starting iteration  470
# starting iteration  480
# starting iteration  490
# starting iteration  500
# Finished epoch 0 / 2: cost 305949.783094, train: 6380222.879156, val 7502230.928562, lr 1.000000e-07
# starting iteration  510
# starting iteration  520
# starting iteration  530
# Finished epoch 1 / 2: cost 319543.731766, train: 6198915.818275, val 7472441.331616, lr 9.500000e-08
# starting iteration  540
# starting iteration  550
# Finished epoch 1 / 2: cost 292665.073239, train: 6132120.711020, val 7462952.682555, lr 9.500000e-08
# starting iteration  560
# starting iteration  570
# starting iteration  580
# starting iteration  590
# starting iteration  600
# Finished epoch 1 / 2: cost 312087.695816, train: 6250664.431430, val 7422374.914869, lr 9.500000e-08
# starting iteration  610
# starting iteration  620
# starting iteration  630
# starting iteration  640
# starting iteration  650
# Finished epoch 1 / 2: cost 324928.141641, train: 6253911.065427, val 7375917.838448, lr 9.500000e-08
# starting iteration  660
# starting iteration  670
# starting iteration  680
# starting iteration  690
# starting iteration  700
# Finished epoch 1 / 2: cost 318077.442202, train: 6095952.385268, val 7317793.990141, lr 9.500000e-08
# starting iteration  710
# starting iteration  720
# starting iteration  730
# starting iteration  740
# starting iteration  750
# Finished epoch 1 / 2: cost 299888.566336, train: 6019212.618339, val 7236791.585541, lr 9.500000e-08
# starting iteration  760
# starting iteration  770
# starting iteration  780
# starting iteration  790
# starting iteration  800
# Finished epoch 1 / 2: cost 305145.647632, train: 5961540.234749, val 7111155.503377, lr 9.500000e-08
# starting iteration  810
# starting iteration  820
# starting iteration  830
# starting iteration  840
# starting iteration  850
# Finished epoch 1 / 2: cost 296986.232698, train: 5757205.202643, val 6900006.224363, lr 9.500000e-08
# starting iteration  860
# starting iteration  870
# starting iteration  880
# starting iteration  890
# starting iteration  900
# Finished epoch 1 / 2: cost 272054.756872, train: 5442540.795249, val 6533398.637363, lr 9.500000e-08
# starting iteration  910
# starting iteration  920
# starting iteration  930
# starting iteration  940
# starting iteration  950
# Finished epoch 1 / 2: cost 244105.823837, train: 4846460.066450, val 5865839.621155, lr 9.500000e-08
# starting iteration  960
# starting iteration  970
# starting iteration  980
# starting iteration  990
# starting iteration  1000
# Finished epoch 1 / 2: cost 6472.417367, train: 151393.884754, val 189406.731920, lr 9.500000e-08
# starting iteration  1010
# starting iteration  1020
# starting iteration  1030
# starting iteration  1040
# starting iteration  1050
# Finished epoch 1 / 2: cost 9596.355814, train: 157934.515175, val 189611.791164, lr 9.500000e-08
# starting iteration  1060
# starting iteration  1070
# Finished epoch 2 / 2: cost 10348.948846, train: 169588.246404, val 203496.083263, lr 9.025000e-08
# finished optimization. best validation accuracy: 189406.731920

# %%
model = init_my_convnet(filter_size=5, num_filters=[32, 64, 128], num_classes=2, num_crp=2, num_affine_layer=1, num_crcrp=0,
                       input_shape=X_train_r.shape[1:], loss="mse")
model = best_model
trainer = RegressionTrainer()
best_model, loss_history, train_acc_history, val_acc_history = trainer.train(
          X_train_r, y_train, X_val_r, y_val, model, my_convnet_imp,
          reg=0.001, momentum=0.9, learning_rate=1e-8, batch_size=50, num_epochs=2,
          acc_frequency=50, verbose=True)
# Out:
# starting iteration  0
# Finished epoch 0 / 2: cost 6973.676529, train: 156219.499213, val 188333.531819, lr 1.000000e-08
# starting iteration  10
# starting iteration  20
# starting iteration  30
# starting iteration  40
# starting iteration  50
# Finished epoch 0 / 2: cost 9571.645837, train: 144511.552641, val 187930.990576, lr 1.000000e-08
# starting iteration  60
# starting iteration  70
# starting iteration  80
# starting iteration  90
# starting iteration  100
# Finished epoch 0 / 2: cost 6077.078359, train: 153193.752097, val 187868.421704, lr 1.000000e-08
# starting iteration  110
# starting iteration  120
# starting iteration  130
# starting iteration  140
# starting iteration  150
# Finished epoch 0 / 2: cost 6897.303253, train: 157543.577447, val 187869.002851, lr 1.000000e-08
# starting iteration  160
# starting iteration  170
# starting iteration  180
# starting iteration  190
# starting iteration  200
# Finished epoch 0 / 2: cost 6344.703928, train: 156660.137155, val 187965.512662, lr 1.000000e-08
# starting iteration  210
# starting iteration  220
# starting iteration  230
# starting iteration  240
# starting iteration  250
# Finished epoch 0 / 2: cost 6642.334832, train: 165000.600580, val 188087.996403, lr 1.000000e-08
# starting iteration  260
# starting iteration  270
# starting iteration  280
# starting iteration  290
# starting iteration  300
# Finished epoch 0 / 2: cost 6473.310655, train: 151286.644379, val 187984.457788, lr 1.000000e-08
# starting iteration  310
# starting iteration  320
# starting iteration  330
# starting iteration  340
# starting iteration  350
# Finished epoch 0 / 2: cost 7876.268771, train: 156259.039288, val 187865.927077, lr 1.000000e-08
# starting iteration  360
# starting iteration  370
# starting iteration  380
# starting iteration  390
# starting iteration  400
# Finished epoch 0 / 2: cost 9532.173280, train: 157133.655565, val 188070.711993, lr 1.000000e-08
# starting iteration  410
# starting iteration  420
# starting iteration  430
# starting iteration  440
# starting iteration  450
# Finished epoch 0 / 2: cost 6848.658371, train: 157670.914989, val 187853.089809, lr 1.000000e-08
# starting iteration  460
# starting iteration  470
# starting iteration  480
# starting iteration  490
# starting iteration  500
# Finished epoch 0 / 2: cost 7963.633303, train: 153022.600580, val 188179.227460, lr 1.000000e-08
# starting iteration  510
# starting iteration  520
# starting iteration  530
# Finished epoch 1 / 2: cost 8654.775205, train: 153123.519377, val 187833.296561, lr 9.500000e-09
# starting iteration  540
# starting iteration  550
# Finished epoch 1 / 2: cost 5751.196957, train: 152651.147762, val 187882.235982, lr 9.500000e-09
# starting iteration  560
# starting iteration  570
# starting iteration  580
# starting iteration  590
# starting iteration  600
# Finished epoch 1 / 2: cost 9931.736842, train: 149773.445400, val 187870.693472, lr 9.500000e-09
# starting iteration  610
# starting iteration  620
# starting iteration  630
# starting iteration  640
# starting iteration  650
# Finished epoch 1 / 2: cost 8073.768089, train: 156593.203590, val 187993.356640, lr 9.500000e-09
# starting iteration  660
# starting iteration  670
# starting iteration  680
# starting iteration  690
# starting iteration  700
# Finished epoch 1 / 2: cost 7951.102990, train: 156109.491054, val 187931.127784, lr 9.500000e-09
# starting iteration  710
# starting iteration  720
# starting iteration  730
# starting iteration  740
# starting iteration  750
# Finished epoch 1 / 2: cost 5451.992561, train: 156969.717768, val 187941.923705, lr 9.500000e-09
# starting iteration  760
# starting iteration  770
# starting iteration  780
# starting iteration  790
# starting iteration  800
# Finished epoch 1 / 2: cost 7681.398302, train: 148960.985757, val 187941.045713, lr 9.500000e-09
# starting iteration  810
# starting iteration  820
# starting iteration  830
# starting iteration  840
# starting iteration  850
# Finished epoch 1 / 2: cost 6806.136113, train: 160783.838925, val 188017.700682, lr 9.500000e-09
# starting iteration  860
# starting iteration  870
# starting iteration  880
# starting iteration  890
# starting iteration  900
# Finished epoch 1 / 2: cost 8579.609424, train: 160947.087778, val 187966.235991, lr 9.500000e-09
# starting iteration  910
# starting iteration  920
# starting iteration  930
# starting iteration  940
# starting iteration  950
# Finished epoch 1 / 2: cost 8816.555248, train: 160611.267908, val 188430.449421, lr 9.500000e-09
# starting iteration  960
# starting iteration  970
# starting iteration  980
# starting iteration  990
# starting iteration  1000
# Finished epoch 1 / 2: cost 7475.210486, train: 156113.444550, val 187967.312430, lr 9.500000e-09
# starting iteration  1010
# starting iteration  1020
# starting iteration  1030
# starting iteration  1040
# starting iteration  1050
# Finished epoch 1 / 2: cost 6046.196318, train: 153589.984397, val 187835.601107, lr 9.500000e-09
# starting iteration  1060
# starting iteration  1070
# Finished epoch 2 / 2: cost 6421.020958, train: 163438.715407, val 188047.446754, lr 9.025000e-09
# finished optimization. best validation accuracy: 187833.296561

# %%
model = np.load("1aff.npy").item()
init_my_convnet(filter_size=5, num_filters=[32, 64], num_classes=2, num_crp=2, num_affine_layer=1, num_crcrp=0,
                       input_shape=X_train_r.shape[1:], loss="mse")
tmp = np.mean(np.abs(my_convnet_imp(X_val_r, model) - y_val), axis=1)
# print tmp
print "Average distance: ", np.sum(tmp)/tmp.shape[0]
# Out:
# Average distance:  13.570844990320055

# %% [markdown]
# I have achieved a similar results as my first HW with -I believe- not a good implementation for regression in CNN's. Also, I have noticed that outputs are so similar to each other and the reason of that is bias that I mistakenly imposed in load_data part. I am loading small amounts of data and loading it sequentially and -then- shuffle it. Therefore big portion of the data is very similar to each other since the datas in the same matrix in dataset are time-series data that comes one after the other. So, what this network finds is essentialy a trend of data points.
#
# Also, while trying this part, I had to change my_convnet_implementation. I didn't had time to refactor the code because of the so less time that I had when implementing this. Even though I did not started too late. Due to my low process power and I have tried many architectures, hyper-parameters in previous tasks, I had not much time for this task.

# %%
model = init_my_convnet(filter_size=5, num_filters=[32, 64], num_classes=2, num_crp=2, num_affine_layer=1, num_crcrp=0,
                       input_shape=X_train_r.shape[1:], loss="mse")
trainer = RegressionTrainer()
best_model, loss_history, train_acc_history, val_acc_history = trainer.train(
          X_train_r, y_train, X_val_r, y_val, model, my_convnet_imp,
          reg=0.001, momentum=0.9, learning_rate=5e-7, batch_size=50, num_epochs=2,
          acc_frequency=50, verbose=True)
# Out:
# starting iteration  0
# Finished epoch 0 / 2: cost 324612.435857, train: 6499783.247937, val 7797428.251212, lr 5.000000e-07
# starting iteration  10
# starting iteration  20
# starting iteration  30
# starting iteration  40
# starting iteration  50
# Finished epoch 0 / 2: cost 317167.193486, train: 6367059.872757, val 7635332.046786, lr 5.000000e-07
# starting iteration  60
# starting iteration  70
# starting iteration  80
# starting iteration  90
# starting iteration  100
# Finished epoch 0 / 2: cost 311347.736095, train: 6208394.238201, val 7445519.471541, lr 5.000000e-07
# starting iteration  110
# starting iteration  120
# starting iteration  130
# starting iteration  140
# starting iteration  150
# Finished epoch 0 / 2: cost 107822.880876, train: 451627.508766, val 542371.341885, lr 5.000000e-07
# starting iteration  160
# starting iteration  170
# starting iteration  180
# starting iteration  190
# starting iteration  200
# Finished epoch 0 / 2: cost 122.297084, train: 3645.812216, val 4314.497306, lr 5.000000e-07
# starting iteration  210
# starting iteration  220
# starting iteration  230
# starting iteration  240
# starting iteration  250
# Finished epoch 0 / 2: cost 53.317434, train: 1475.800805, val 1643.926092, lr 5.000000e-07
# starting iteration  260
# starting iteration  270
# starting iteration  280
# starting iteration  290
# starting iteration  300
# Finished epoch 0 / 2: cost 84.331251, train: 1315.104362, val 1584.853165, lr 5.000000e-07
# starting iteration  310
# starting iteration  320
# starting iteration  330
# starting iteration  340
# starting iteration  350
# Finished epoch 0 / 2: cost 89.069471, train: 1165.286942, val 1503.342413, lr 5.000000e-07
# starting iteration  360
# starting iteration  370
# starting iteration  380
# starting iteration  390
# starting iteration  400
# Finished epoch 0 / 2: cost 51.965450, train: 1227.841795, val 1592.284667, lr 5.000000e-07
# starting iteration  410
# starting iteration  420
# starting iteration  430
# starting iteration  440
# starting iteration  450
# Finished epoch 0 / 2: cost 96.429230, train: 1245.076486, val 1511.198394, lr 5.000000e-07
# starting iteration  460
# starting iteration  470
# starting iteration  480
# starting iteration  490
# starting iteration  500
# Finished epoch 0 / 2: cost 46.043985, train: 1022.479844, val 1506.271270, lr 5.000000e-07
# starting iteration  510
# starting iteration  520
# starting iteration  530
# Finished epoch 1 / 2: cost 65.154909, train: 1174.560734, val 1530.721427, lr 4.750000e-07
# starting iteration  540
# starting iteration  550
# Finished epoch 1 / 2: cost 101.154186, train: 1356.106545, val 1559.601519, lr 4.750000e-07
# starting iteration  560
# starting iteration  570
# starting iteration  580
# starting iteration  590
# starting iteration  600
# Finished epoch 1 / 2: cost 49.817756, train: 1221.857857, val 1536.920532, lr 4.750000e-07
# starting iteration  610
# starting iteration  620
# starting iteration  630
# starting iteration  640
# starting iteration  650
# Finished epoch 1 / 2: cost 96.875445, train: 1310.658737, val 1547.093989, lr 4.750000e-07
# starting iteration  660
# starting iteration  670
# starting iteration  680
# starting iteration  690
# starting iteration  700
# Finished epoch 1 / 2: cost 94.095527, train: 1280.818888, val 1503.369458, lr 4.750000e-07
# starting iteration  710
# starting iteration  720
# starting iteration  730
# starting iteration  740
# starting iteration  750
# Finished epoch 1 / 2: cost 87.944700, train: 1081.388663, val 1505.188315, lr 4.750000e-07
# starting iteration  760
# starting iteration  770
# starting iteration  780
# starting iteration  790
# starting iteration  800
# Finished epoch 1 / 2: cost 70.959384, train: 1280.045895, val 1519.387766, lr 4.750000e-07
# starting iteration  810
# starting iteration  820
# starting iteration  830
# starting iteration  840
# starting iteration  850
# Finished epoch 1 / 2: cost 50.059754, train: 1463.034751, val 1555.863787, lr 4.750000e-07
# starting iteration  860
# starting iteration  870
# starting iteration  880
# starting iteration  890
# starting iteration  900
# Finished epoch 1 / 2: cost 96.847189, train: 1387.703411, val 1522.451439, lr 4.750000e-07
# starting iteration  910
# starting iteration  920
# starting iteration  930
# starting iteration  940
# starting iteration  950
# Finished epoch 1 / 2: cost 84.786118, train: 1173.093105, val 1553.717723, lr 4.750000e-07
# starting iteration  960
# starting iteration  970
# starting iteration  980
# starting iteration  990
# starting iteration  1000
# Finished epoch 1 / 2: cost 61.089972, train: 1136.289300, val 1509.675800, lr 4.750000e-07
# starting iteration  1010
# starting iteration  1020
# starting iteration  1030
# starting iteration  1040
# starting iteration  1050
# Finished epoch 1 / 2: cost 68.941851, train: 1294.102257, val 1507.382481, lr 4.750000e-07
# starting iteration  1060
# starting iteration  1070
# Finished epoch 2 / 2: cost 37.481321, train: 1301.607921, val 1564.263331, lr 4.512500e-07
# finished optimization. best validation accuracy: 1503.342413

# %%
model = init_my_convnet(filter_size=5, num_filters=[32, 64], num_classes=2, num_crp=2, num_affine_layer=1, num_crcrp=0,
                       input_shape=X_train_r.shape[1:], loss="mse")
model = best_model
trainer = RegressionTrainer()
best_model, loss_history, train_acc_history, val_acc_history = trainer.train(
          X_train_r, y_train, X_val_r, y_val, model, my_convnet_imp,
          reg=0.001, momentum=0.9, learning_rate=5e-9, batch_size=50, num_epochs=5,
          acc_frequency=50, verbose=True)
# Out:
# starting iteration  0
# Finished epoch 0 / 5: cost 31.828135, train: 1229.111039, val 1503.233751, lr 5.000000e-09
# starting iteration  10
# starting iteration  20
# starting iteration  30
# starting iteration  40
# starting iteration  50
# Finished epoch 0 / 5: cost 54.816400, train: 1286.951597, val 1501.331774, lr 5.000000e-09
# starting iteration  60
# starting iteration  70
# starting iteration  80
# starting iteration  90
# starting iteration  100
# Finished epoch 0 / 5: cost 55.971776, train: 1035.640778, val 1501.982243, lr 5.000000e-09
# starting iteration  110
# starting iteration  120
# starting iteration  130
# starting iteration  140
# starting iteration  150
# Finished epoch 0 / 5: cost 50.744793, train: 1404.831411, val 1501.361529, lr 5.000000e-09
# starting iteration  160
# starting iteration  170
# starting iteration  180
# starting iteration  190
# starting iteration  200
# Finished epoch 0 / 5: cost 61.882992, train: 1203.537690, val 1501.035714, lr 5.000000e-09
# starting iteration  210
# starting iteration  220
# starting iteration  230
# starting iteration  240
# starting iteration  250
# Finished epoch 0 / 5: cost 32.947888, train: 1161.546720, val 1501.982283, lr 5.000000e-09
# starting iteration  260
# starting iteration  270
# starting iteration  280
# starting iteration  290
# starting iteration  300
# Finished epoch 0 / 5: cost 58.105880, train: 1034.161244, val 1501.095080, lr 5.000000e-09
# starting iteration  310
# starting iteration  320
# starting iteration  330
# starting iteration  340
# starting iteration  350
# Finished epoch 0 / 5: cost 40.506654, train: 1209.019474, val 1501.353939, lr 5.000000e-09
# starting iteration  360
# starting iteration  370
# starting iteration  380
# starting iteration  390
# starting iteration  400
# Finished epoch 0 / 5: cost 63.040827, train: 984.979327, val 1501.170722, lr 5.000000e-09
# starting iteration  410
# starting iteration  420
# starting iteration  430
# starting iteration  440
# starting iteration  450
# Finished epoch 0 / 5: cost 37.499329, train: 1052.343240, val 1501.820476, lr 5.000000e-09
# starting iteration  460
# starting iteration  470
# starting iteration  480
# starting iteration  490
# starting iteration  500
# Finished epoch 0 / 5: cost 53.738630, train: 1212.815123, val 1501.558477, lr 5.000000e-09
# starting iteration  510
# starting iteration  520
# starting iteration  530
# Finished epoch 1 / 5: cost 45.669622, train: 1157.565556, val 1501.117657, lr 4.750000e-09
# starting iteration  540
# starting iteration  550
# Finished epoch 1 / 5: cost 63.726474, train: 1173.077214, val 1501.170859, lr 4.750000e-09
# starting iteration  560
# starting iteration  570
# starting iteration  580
# starting iteration  590
# starting iteration  600
# Finished epoch 1 / 5: cost 70.116060, train: 1048.092565, val 1502.232425, lr 4.750000e-09
# starting iteration  610
# starting iteration  620
# starting iteration  630
# starting iteration  640
# starting iteration  650
# Finished epoch 1 / 5: cost 87.089787, train: 1149.252568, val 1501.606607, lr 4.750000e-09
# starting iteration  660
# starting iteration  670
# starting iteration  680
# starting iteration  690
# starting iteration  700
# Finished epoch 1 / 5: cost 38.590600, train: 1238.719278, val 1502.498674, lr 4.750000e-09
# starting iteration  710
# starting iteration  720
# starting iteration  730
# starting iteration  740
# starting iteration  750
# Finished epoch 1 / 5: cost 55.983487, train: 1099.758260, val 1501.541834, lr 4.750000e-09
# starting iteration  760
# starting iteration  770
# starting iteration  780
# starting iteration  790
# starting iteration  800
# Finished epoch 1 / 5: cost 38.766840, train: 1212.203637, val 1500.955235, lr 4.750000e-09
# starting iteration  810
# starting iteration  820
# starting iteration  830
# starting iteration  840
# starting iteration  850
# Finished epoch 1 / 5: cost 70.669843, train: 1251.637389, val 1502.335952, lr 4.750000e-09
# starting iteration  860
# starting iteration  870
# starting iteration  880
# starting iteration  890
# starting iteration  900
# Finished epoch 1 / 5: cost 70.881833, train: 1344.757884, val 1501.811003, lr 4.750000e-09
# starting iteration  910
# starting iteration  920
# starting iteration  930
# starting iteration  940
# starting iteration  950
# Finished epoch 1 / 5: cost 63.355705, train: 1358.882416, val 1502.115216, lr 4.750000e-09
# starting iteration  960
# starting iteration  970
# starting iteration  980
# starting iteration  990
# starting iteration  1000
# Finished epoch 1 / 5: cost 44.449801, train: 1245.346384, val 1501.559914, lr 4.750000e-09
# starting iteration  1010
# starting iteration  1020
# starting iteration  1030
# starting iteration  1040
# starting iteration  1050
# Finished epoch 1 / 5: cost 96.346020, train: 1405.598648, val 1502.094065, lr 4.750000e-09
# starting iteration  1060
# starting iteration  1070
# Finished epoch 2 / 5: cost 44.560749, train: 1190.710642, val 1501.006711, lr 4.512500e-09
# starting iteration  1080
# starting iteration  1090
# starting iteration  1100
# Finished epoch 2 / 5: cost 95.887462, train: 1283.557521, val 1501.739405, lr 4.512500e-09
# starting iteration  1110
# starting iteration  1120
# starting iteration  1130
# starting iteration  1140
# starting iteration  1150
# Finished epoch 2 / 5: cost 46.537831, train: 1299.645373, val 1501.171750, lr 4.512500e-09
# starting iteration  1160
# starting iteration  1170
# starting iteration  1180
# starting iteration  1190
# starting iteration  1200
# Finished epoch 2 / 5: cost 43.833427, train: 1176.467674, val 1501.263426, lr 4.512500e-09
# starting iteration  1210
# starting iteration  1220
# starting iteration  1230
# starting iteration  1240
# starting iteration  1250
# Finished epoch 2 / 5: cost 71.552032, train: 1217.923418, val 1501.116964, lr 4.512500e-09
# starting iteration  1260
# starting iteration  1270
# starting iteration  1280
# starting iteration  1290
# starting iteration  1300
# Finished epoch 2 / 5: cost 54.422285, train: 1243.484408, val 1502.131990, lr 4.512500e-09
# starting iteration  1310
# starting iteration  1320
# starting iteration  1330
# starting iteration  1340
# starting iteration  1350
# Finished epoch 2 / 5: cost 69.565903, train: 1304.454970, val 1501.442569, lr 4.512500e-09
# starting iteration  1360
# starting iteration  1370
# starting iteration  1380
# starting iteration  1390
# starting iteration  1400
# Finished epoch 2 / 5: cost 83.435107, train: 1194.141972, val 1501.337889, lr 4.512500e-09
# starting iteration  1410
# starting iteration  1420
# starting iteration  1430
# starting iteration  1440
# starting iteration  1450
# Finished epoch 2 / 5: cost 55.022446, train: 1404.304774, val 1501.289947, lr 4.512500e-09
# starting iteration  1460
# starting iteration  1470
# starting iteration  1480
# starting iteration  1490
# starting iteration  1500
# Finished epoch 2 / 5: cost 50.459133, train: 1350.487109, val 1502.155789, lr 4.512500e-09
# starting iteration  1510
# starting iteration  1520
# starting iteration  1530
# starting iteration  1540
# starting iteration  1550
# Finished epoch 2 / 5: cost 45.473762, train: 1270.851023, val 1501.383220, lr 4.512500e-09
# starting iteration  1560
# starting iteration  1570
# starting iteration  1580
# starting iteration  1590
# starting iteration  1600
# Finished epoch 2 / 5: cost 75.891399, train: 1241.545637, val 1501.719180, lr 4.512500e-09
# starting iteration  1610
# Finished epoch 3 / 5: cost 55.177875, train: 1280.078373, val 1501.064032, lr 4.286875e-09
# starting iteration  1620
# starting iteration  1630
# starting iteration  1640
# starting iteration  1650
# Finished epoch 3 / 5: cost 47.375164, train: 1167.055483, val 1501.222459, lr 4.286875e-09
# starting iteration  1660
# starting iteration  1670
# starting iteration  1680
# starting iteration  1690
# starting iteration  1700
# Finished epoch 3 / 5: cost 57.716585, train: 1151.615552, val 1501.175614, lr 4.286875e-09
# starting iteration  1710
# starting iteration  1720
# starting iteration  1730
# starting iteration  1740
# starting iteration  1750
# Finished epoch 3 / 5: cost 54.720427, train: 1338.621589, val 1504.877413, lr 4.286875e-09
# starting iteration  1760
# starting iteration  1770
# starting iteration  1780
# starting iteration  1790
# starting iteration  1800
# Finished epoch 3 / 5: cost 63.144788, train: 1207.364798, val 1501.238146, lr 4.286875e-09
# starting iteration  1810
# starting iteration  1820
# starting iteration  1830
# starting iteration  1840
# starting iteration  1850
# Finished epoch 3 / 5: cost 67.536588, train: 1267.411024, val 1501.135681, lr 4.286875e-09
# starting iteration  1860
# starting iteration  1870
# starting iteration  1880
# starting iteration  1890
# starting iteration  1900
# Finished epoch 3 / 5: cost 44.738310, train: 1352.092371, val 1502.492799, lr 4.286875e-09
# starting iteration  1910
# starting iteration  1920
# starting iteration  1930
# starting iteration  1940
# starting iteration  1950
# Finished epoch 3 / 5: cost 110.799896, train: 1350.119692, val 1502.438799, lr 4.286875e-09
# starting iteration  1960
# starting iteration  1970
# starting iteration  1980
# starting iteration  1990
# starting iteration  2000
# Finished epoch 3 / 5: cost 58.197184, train: 1360.447916, val 1501.949678, lr 4.286875e-09
# starting iteration  2010
# starting iteration  2020
# starting iteration  2030
# starting iteration  2040
# starting iteration  2050
# Finished epoch 3 / 5: cost 56.068417, train: 1311.753526, val 1501.186319, lr 4.286875e-09
# starting iteration  2060
# starting iteration  2070
# starting iteration  2080
# starting iteration  2090
# starting iteration  2100
# Finished epoch 3 / 5: cost 40.534185, train: 1322.484428, val 1502.197584, lr 4.286875e-09
# starting iteration  2110
# starting iteration  2120
# starting iteration  2130
# starting iteration  2140
# starting iteration  2150
# Finished epoch 3 / 5: cost 65.450838, train: 1419.282844, val 1501.332444, lr 4.286875e-09
# Finished epoch 4 / 5: cost 64.501946, train: 1387.085823, val 1501.188443, lr 4.072531e-09
# starting iteration  2160
# starting iteration  2170
# starting iteration  2180
# starting iteration  2190
# starting iteration  2200
# Finished epoch 4 / 5: cost 29.933045, train: 1166.329038, val 1501.766478, lr 4.072531e-09
# starting iteration  2210
# starting iteration  2220
# starting iteration  2230
# starting iteration  2240
# starting iteration  2250
# Finished epoch 4 / 5: cost 57.992030, train: 1169.275118, val 1501.427245, lr 4.072531e-09
# starting iteration  2260
# starting iteration  2270
# starting iteration  2280
# starting iteration  2290
# starting iteration  2300
# Finished epoch 4 / 5: cost 50.084823, train: 1218.836753, val 1501.227724, lr 4.072531e-09
# starting iteration  2310
# starting iteration  2320
# starting iteration  2330
# starting iteration  2340
# starting iteration  2350
# Finished epoch 4 / 5: cost 102.038378, train: 1281.283031, val 1500.964595, lr 4.072531e-09
# starting iteration  2360
# starting iteration  2370
# starting iteration  2380
# starting iteration  2390
# starting iteration  2400
# Finished epoch 4 / 5: cost 66.717179, train: 1079.024540, val 1501.631865, lr 4.072531e-09
# starting iteration  2410
# starting iteration  2420
# starting iteration  2430
# starting iteration  2440
# starting iteration  2450
# Finished epoch 4 / 5: cost 65.777368, train: 1150.124012, val 1501.550276, lr 4.072531e-09
# starting iteration  2460
# starting iteration  2470
# starting iteration  2480
# starting iteration  2490
# starting iteration  2500
# Finished epoch 4 / 5: cost 82.334812, train: 1439.357798, val 1501.026895, lr 4.072531e-09
# starting iteration  2510
# starting iteration  2520
# starting iteration  2530
# starting iteration  2540
# starting iteration  2550
# Finished epoch 4 / 5: cost 35.057553, train: 1166.012044, val 1500.950575, lr 4.072531e-09
# starting iteration  2560
# starting iteration  2570
# starting iteration  2580
# starting iteration  2590
# starting iteration  2600
# Finished epoch 4 / 5: cost 93.229192, train: 1273.809108, val 1501.269081, lr 4.072531e-09
# starting iteration  2610
# starting iteration  2620
# starting iteration  2630
# starting iteration  2640
# starting iteration  2650
# Finished epoch 4 / 5: cost 51.516928, train: 1376.087883, val 1501.850784, lr 4.072531e-09
# starting iteration  2660
# starting iteration  2670
# starting iteration  2680
# starting iteration  2690
# Finished epoch 5 / 5: cost 47.736995, train: 1334.727581, val 1500.967674, lr 3.868905e-09
# finished optimization. best validation accuracy: 1500.950575

# %%
tmp = np.mean(np.abs(my_convnet_imp(X_val_r, best_model) - y_val), axis=1)
print "Average distance: ", np.sum(tmp)/tmp.shape[0]

tmp = np.mean(np.abs(my_convnet_imp(X_test_r, best_model) - y_test), axis=1)
print "Average distance: ", np.sum(tmp)/tmp.shape[0]
# Out:
# 144.1389517078341 62.91120630284322
# Average distance:  1.052381957799357

# %% [markdown]
# I have further spent time and randomized the data selection part. And as we can see, scores are now closer to each other and has greater accuracy.
